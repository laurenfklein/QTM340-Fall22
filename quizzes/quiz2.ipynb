# %% [markdown]
# # Quiz 2
# *Formerly quiz 3*
#
# Your second quiz asks you to put some of your newly acquired methods of text analysis into action.
#
# **Your assignment is as follows:**
#
# 1. Pick ONE of either TF-IDF, topic modeling, or word2vec, and apply that method to the corpus which the code cells just below will allow you to access: it's a corpus of approximately 150,000 Yelp reviews of restaurants, which I pulled out of the [Yelp Open Dataset](https://www.yelp.com/dataset).
#
# 2. Upon completing the task above, answer the four questions at the bottom of the notebook. Just a few sentences is fine for each.
#
# **Process:**
#
# Please make a copy of this notebook, inserting your code where specified and inserting any additional cells as you see fit.
#
# Please be sure to at least minimally comment your code so that the grader can follow along!
#
# Please upload your completed notebook to the assignment page on Canvas.

# %% [markdown]
# ### Step 0. Load in the data
#
# Run the two cells below to get the data for this quiz imported into your Colab workspace.
#
# This will result in local directory (folder) called "reviews" that should serve as your base directory for any future operations. (The equivalent of the "wheel-clean" directory we've used in the past).

# %%
# Load in the data 

# For downloading large files from Google Drive
import gdown

# Then download the zip file
gdown.download('https://drive.google.com/uc?export=download&id=1BfOVtHxeFZxdSjGhhyu3dy4eUCfS4BmI', quiet=False)

# %%
# unzip it 
# !unzip reviews.zip

# %% [markdown]
# And you're good to go!
#
# The cells below are intended to structure your work for this assginment. Feel free to add more (and in fact you will certainly *need* to add more) depending on the method you choose to implement.
#
# Please also don't forget to answer the two questions at the end of the notebook.
#
# ### Step 1. Pre-process your data

# %%
# Here are some placeholder code cells where you should place any text pre-processing code that your method requires
# Note that if you've unzipped the file as above, it will result in a local folder called "reviews" that should serve 
# as your base directory for any future operations.

# %% [markdown]
# ### Step 2. Run the method

# %%
# Here are some placeholder code cells where you should place the code to actually run the method on your data

# %% [markdown]
# ### Step 3. Explore the results

# %%
# Here are some placeholder code cells where you should place the code that allows you to explore the output of 
# your model. For this section, use the sample code from the relevant notebook as a guide.

# %% [markdown]
# **Question 1. Generally speaking, what did you learn about your dataset from the modeling approach that you chose?**

# %% [markdown]
# *Your answer here!*

# %% [markdown]
# **Question 2. Are there any improvements and/or modifications you might make to your approach if you were to try to get better/more interesting results?**

# %% [markdown]
# *Your answer here!*

# %% [markdown]
# **Question 3. Improvements notwithstanding, what is one specific interesting thing that you found?**

# %% [markdown]
# *Your answer here!*

# %% [markdown]
# **Question 4. What is a research question you might ask that is prompted by this finding, or by your modeling approach in general?**

# %% [markdown]
# *Your answer here!*
